# %%
import requests
import json
import yaml

# %%
def load_config():
    with open('config.yml', 'r') as file:
        return yaml.safe_load(file)

# %%
config = load_config()
API_key = config['open_wheather_api']['key']
city_name = 'Paris'
limit = 5
url = f"http://api.openweathermap.org/geo/1.0/direct?q={city_name}&limit={limit}&appid={API_key}"

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
if page.status_code == 200: 
    page_json = page.json()
page_json
# Out:
# [{'name': 'Paris',
#   'local_names': {'yo': 'Parisi',
#    'cs': 'Paříž',
#    'eo': 'Parizo',
#    'bo': 'ཕ་རི།',
#    'te': 'పారిస్',
#    'lb': 'Paräis',
#    'ha': 'Pariis',
#    'ne': 'पेरिस',
#    'sc': 'Parigi',
#    'kn': 'ಪ್ಯಾರಿಸ್',
#    'hu': 'Párizs',
#    'wo': 'Pari',
#    'ru': 'Париж',
#    'is': 'París',
#    'zh': '巴黎',
#    'eu': 'Paris',
#    'hi': 'पैरिस',
#    'ml': 'പാരിസ്',
#    'tk': 'Pariž',
#    'mr': 'पॅरिस',
#    'pa': 'ਪੈਰਿਸ',
#    'uk': 'Париж',
#    'gv': 'Paarys',
#    'so': 'Baariis',
#    'ka': 'პარიზი',
#    'sv': 'Paris',
#    'el': 'Παρίσι',
#    'ar': 'باريس',
#    'ht': 'Pari',
#    'de': 'Paris',
#    'fr': 'Paris',
#    'la': 'Lutetia',
#    'kk': 'Париж',
#    'bn': 'প্যারিস',
#    'gl': 'París',
#    'an': 'París',
#    'hr': 'Pariz',
#    'it': 'Parigi',
#    'ga': 'Páras',
#    'ug': 'پارىژ',
#    'br': 'Pariz',
#    'no': 'Paris',
#    'lt': 'Paryžius',
#    'fa': 'پاریس',
#    'pl': 'Paryż',
#    'gu': 'પૅરિસ',
#    'ps': 'پاريس',
# ...

# %%
with open('data_loc.json', 'w', encoding='utf-8') as fichier:
        json.dump(page_json, fichier, indent=4)

# %%
lats = []
lons = []
for i in range(len(page_json)):
    if page_json[i]['country'] == 'FR':
        lats.append(page_json[i]['lat'])
        lons.append(page_json[i]['lon'])
lats, lons
# Out:
# ([48.8588897, 48.8534951, 48.8588897],
#  [2.3200410217200766, 2.3483915, 2.3200410217200766])

# %%
url2 = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}"
page2 = requests.get(url2)
page2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 url2 = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}"
#       2 page2 = requests.get(url2)
#       3 page2
#
# NameError: name 'lat' is not defined

# %%
if page2.status_code == 200:
    page2_json = page2.json()
page2_json
# Out:
# {'coord': {'lon': 2.32, 'lat': 48.8589},
#  'weather': [{'id': 501,
#    'main': 'Rain',
#    'description': 'moderate rain',
#    'icon': '10d'}],
#  'base': 'stations',
#  'main': {'temp': 282.56,
#   'feels_like': 279,
#   'temp_min': 282.01,
#   'temp_max': 283.23,
#   'pressure': 1012,
#   'humidity': 93},
#  'visibility': 8000,
#  'wind': {'speed': 8.23, 'deg': 200},
#  'rain': {'1h': 1.26},
#  'clouds': {'all': 100},
#  'dt': 1708528012,
#  'sys': {'type': 2,
#   'id': 2012208,
#   'country': 'FR',
#   'sunrise': 1708498176,
#   'sunset': 1708535974},
#  'timezone': 3600,
#  'id': 6545270,
#  'name': 'Palais-Royal',
#  'cod': 200}

# %%
with open('data_wheather.json', 'w', encoding='utf-8') as fichier:
    json.dump(page2_json, fichier, indent=4)

# %%
infos = []
for lat, lon in zip(lats, lons):
     infos.append(requests.get(f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}").json())
infos
# Out:
# [{'coord': {'lon': 2.32, 'lat': 48.8589},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 282.56,
#    'feels_like': 279,
#    'temp_min': 282.01,
#    'temp_max': 283.23,
#    'pressure': 1012,
#    'humidity': 93},
#   'visibility': 8000,
#   'wind': {'speed': 8.23, 'deg': 200},
#   'rain': {'1h': 1.26},
#   'clouds': {'all': 100},
#   'dt': 1708528012,
#   'sys': {'type': 2,
#    'id': 2012208,
#    'country': 'FR',
#    'sunrise': 1708498176,
#    'sunset': 1708535974},
#   'timezone': 3600,
#   'id': 6545270,
#   'name': 'Palais-Royal',
#   'cod': 200},
#  {'coord': {'lon': 2.3484, 'lat': 48.8535},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 282.55,
#    'feels_like': 279.12,
#    'temp_min': 282.03,
#    'temp_max': 283.25,
#    'pressure': 1012,
# ...
